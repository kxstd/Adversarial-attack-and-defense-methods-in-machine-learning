# %% [markdown]
# # 可视化与思考

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import transforms as tt
import torchvision.models as models
import timm
from PIL import Image as pil
import os
import numpy as np
import torch
import pickle
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import utils
from numpy import linalg as LA
import matplotlib.pyplot as plt
import random
to_pil=tt.ToPILImage()

# %%
patch_sample_path='./patch_sample.txt'
pgd_sample_path='./pgd_sample.txt'
pgd_inf_sample_path='./pgd_inf_sample.txt'

with open(pgd_sample_path,'rb') as f:
        pgd_sample=pickle.load(f)
with open(pgd_inf_sample_path,'rb') as f:
        pgd_inf_sample=pickle.load(f)

with open(patch_sample_path,'rb') as f:
        patch_sample=pickle.load(f)
        
simba_sample_path='./simba_sample.txt'        
with open(simba_sample_path,'rb') as f:
        simba_sample=pickle.load(f)

# %%
id=0
for image, label in patch_sample["vit"]:
    id+=1
    #if(id!=5):continue
    img=to_pil(image[0])
    plt.subplot(2,3,id)
    plt.imshow(img)
    print(label)
    
    if id==6:break
# Out:
# tensor([651], dtype=torch.int32)
# tensor([141], dtype=torch.int32)
# tensor([913], dtype=torch.int32)
# tensor([511], dtype=torch.int32)
# tensor([969], dtype=torch.int32)
# tensor([314], dtype=torch.int32)

# %%
i=random.randint(0,10)
j=random.randint(0,10)

# %%
i,j
# Out:
# (3, 3)

# %%
plt.imshow(to_pil(patch_sample["res"][4][0][0]).save("1.png"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-93d46017e2d5> in <module>
# ----> 1 plt.imshow(to_pil(patch_sample["res"][4][0][0]).save("1.png"))
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     700         if (self._A.dtype != np.uint8 and
#     701                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 702             raise TypeError("Image data of dtype {} cannot be converted to "
#     703                             "float".format(self._A.dtype))
#     704
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
# Out:
# tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0056, 0.0000],
#          ...,
#          [0.4166, 0.4337, 0.4508,  ..., 0.7077, 0.6906, 0.6392],
#          [0.4508, 0.4337, 0.4337,  ..., 0.9988, 0.9817, 1.0000],
#          [0.4337, 0.4679, 0.4508,  ..., 1.0000, 1.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0301, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0301, 0.0476, 0.0126],
#          ...,
#          [0.3452, 0.3627, 0.3803,  ..., 0.6078, 0.5903, 0.5378],
#          [0.3627, 0.3627, 0.3627,  ..., 0.8529, 0.8004, 0.8704],
#          [0.3452, 0.3627, 0.3803,  ..., 1.0000, 1.0000, 1.0000]],
#
#         [[0.0000, 0.0000, 0.0000,  ..., 0.0256, 0.1302, 0.1476],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0256, 0.1999, 0.1476],
#          [0.0000, 0.0000, 0.0000,  ..., 0.1302, 0.1999, 0.1302],
#          ...,
#          [0.3393, 0.3393, 0.3219,  ..., 0.6879, 0.7228, 0.7054],
#          [0.4265, 0.3393, 0.3393,  ..., 0.8797, 0.8274, 0.9145],
#          [0.4091, 0.3568, 0.3568,  ..., 1.0000, 1.0000, 1.0000]]])
