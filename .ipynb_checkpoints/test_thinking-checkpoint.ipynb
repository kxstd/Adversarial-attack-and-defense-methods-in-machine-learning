# %% [markdown]
# # 可视化与思考

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import transforms as tt
import torchvision.models as models
import timm
from PIL import Image as pil
import os
import numpy as np
import torch
import pickle
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import utils
from numpy import linalg as LA
import matplotlib.pyplot as plt
to_pil=tt.ToPILImage()

# %%
patch_sample_path='./patch_sample.txt'
pgd_sample_path='./pgd_sample.txt'
pgd_inf_sample_path='./pgd_inf_sample.txt'

with open(pgd_sample_path,'rb') as f:
        pgd_sample=pickle.load(f)
with open(pgd_inf_sample_path,'rb') as f:
        pgd_inf_sample=pickle.load(f)

with open(patch_sample_path,'rb') as f:
        patch_sample=pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b41165594ead> in <module>
#       8         pgd_inf_sample=pickle.load(f)
#       9
# ---> 10 with open(patch_sample_path,'rb') as f:
#      11         patch_sample=pickle.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: './patch_sample.txt'

# %%
id=0

for image, label in pgd_inf_sample["vit"]:
    id+=1
    img=to_pil(image[0])
    plt.subplot(2,3,id)
    plt.imshow(img)
    
    if id==6:break
